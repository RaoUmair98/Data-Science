# %% [markdown]
# **Data Visualization**

# %%
# %ls
# Out:
#  BankChurners.csv   'Graphs.ipynb - Colaboratory_files'/   Project1.csv
#  BankChurnersq.csv  'Graphs.ipynb - Colaboratory.html'

# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlp
# %matplotlib inline
from sklearn import datasets
import seaborn as sns

# %%
df = pd.read_csv("Project1.csv")
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     item_id          status created_at  ... Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0  211131.0        complete   7/1/2016  ...         NaN          NaN          NaN
# 1  211133.0        canceled   7/1/2016  ...         NaN          NaN          NaN
# 2  211134.0        canceled   7/1/2016  ...         NaN          NaN          NaN
# 3  211135.0        complete   7/1/2016  ...         NaN          NaN          NaN
# 4  211136.0  order_refunded   7/1/2016  ...         NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
df.columns

# %%
df.describe()

# %%
df.info()

# %%
df.dtypes

# %%
#df1 = (df['status'],df['payment_method'])
#df1
df['status'].corr(df['payment_method'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-594d13629758> in <module>()
#       1 #df1 = (df['status'],df['payment_method'])
#       2 #df1
# ----> 3 df['status'].corr(df['payment_method'])
#       4 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2333         if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2334             return nanops.nancorr(
# -> 2335                 this.values, other.values, method=method, min_periods=min_periods
#    2336             )
#    2337
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
# ...

# %%
df.isnull()

# %%
df.fillna(0)

# %%
df.isnull().sum()

# %%
df1 = df.dropna()
df1
df1.isnull()

# %%
df.shape

# %%
dfobj=df.select_dtypes(object)
dfobj

# %%
dfobj['status'].unique()

# %%
payment_method = df["payment_method"]
status = df["status"]
correlation = payment_method.corr(status)
print(correlation)

# %%
df = pd.read_csv('Project1.csv')
df.corr[['status' ] ['payment_method']]
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-35fbebeba61e> in <module>()
#       1 df = pd.read_csv('Project1.csv')
# ----> 2 df.corr[['status' ] ['payment_method']]
#
# TypeError: list indices must be integers or slices, not str
